# %% [markdown]
# # Modelling league dash data

# %%
# import pickle
import pandas as pd
from pathlib import Path

# %%
fp = Path("../data/leaguedash_merge_2018-19.pkl")
# with open(fp, "rb") as f:
#     tor = pickle.load(f)
tor = pd.read_pickle(fp)
tor.sample(6)
# Out:
#                 PLAYER_NAME TEAM_ABBREVIATION   AGE   GP_merge    MIN_merge  \
# PLAYER_ID
# 1626170        Jerian Grant               ORL  26.0  54.818182   854.704545
# 1628398          Kyle Kuzma               LAL  23.0  70.000000  2313.581667
# 203925           Joe Harris               BKN  27.0  67.744186  2044.197248
# 1627734    Domantas Sabonis               IND  23.0  67.170732  1668.460325
# 204025          Tim Frazier               MIL  28.0  45.962963   826.370288
# 1626164        Devin Booker               PHX  22.0  64.000000  2242.118333
#
#            FG3M_merge  FG3A_merge  FTM_merge  FTA_merge  OREB_merge  ...  \
# PLAYER_ID                                                            ...
# 1626170      1.363636    5.454545   1.145455   1.600000    0.636364  ...
# 1628398      2.000000    6.600000   2.900000   3.900000    0.900000  ...
# 203925       2.679070    5.983721   1.723256   2.076744    0.869767  ...
# 1627734      0.219512    0.417073   4.031707   5.651220    3.502439  ...
# 204025       1.607407    3.797531   1.435802   1.727160    0.946914  ...
# 1626164      2.200000    6.600000   6.300000   7.300000    0.600000  ...
#
#            TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  \
# PLAYER_ID
# 1626170         189        94       433        459      316       220
# 1628398         179       446       315         94      380       181
# 203925          218       440       388        105      320       365
# 1627734          63       323       243        318       79        33
# 204025          117       309       444        197      157       235
# 1626164          11       343       423         81      261        16
#
#            PTS_RANK  PLUS_MINUS_RANK  FG2M_RANK  FG2A_RANK
# PLAYER_ID
# 1626170         461              249        423        433
# 1628398          66              244        109        140
# 203925          190              338        348        390
# 1627734          81              125         33         54
# 204025          354              395        339        391
# 1626164          11              415         40         39
#
# [6 rows x 41 columns]

# %%
tor[tor["PLAYER_NAME"] == "Kawhi Leonard"]
# Out:
#              PLAYER_NAME TEAM_ABBREVIATION   AGE  GP_merge    MIN_merge  \
# PLAYER_ID
# 202695     Kawhi Leonard               TOR  28.0      44.0  1550.974444
#
#            FG3M_merge  FG3A_merge  FTM_merge  FTA_merge  OREB_merge  ...  \
# PLAYER_ID                                                            ...
# 202695       2.044444    5.433333        6.8   7.855556    1.711111  ...
#
#            TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  \
# PLAYER_ID
# 202695          121        64       248        124      494        11
#
#            PTS_RANK  PLUS_MINUS_RANK  FG2M_RANK  FG2A_RANK
# PLAYER_ID
# 202695            6               47         31         29
#
# [1 rows x 41 columns]

# %%
tor.columns
# Out:
# Index(['PLAYER_NAME', 'TEAM_ABBREVIATION', 'AGE', 'GP_merge', 'MIN_merge',
#        'FG3M_merge', 'FG3A_merge', 'FTM_merge', 'FTA_merge', 'OREB_merge',
#        'DREB_merge', 'AST_merge', 'TOV_merge', 'STL_merge', 'BLK_merge',
#        'BLKA_merge', 'PF_merge', 'PFD_merge', 'PTS_merge', 'PLUS_MINUS_merge',
#        'FG2M_merge', 'FG2A_merge', 'GP_RANK', 'MIN_RANK', 'FG3M_RANK',
#        'FG3A_RANK', 'FTM_RANK', 'FTA_RANK', 'OREB_RANK', 'DREB_RANK',
#        'AST_RANK', 'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK',
#        'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK', 'FG2M_RANK', 'FG2A_RANK'],
#       dtype='object')

# %%
fp = Path("../data/leaguedash_merge_2004-05.pkl")
# with open(fp, "rb") as f:
#     det = pickle.load(f)
det = pd.read_pickle(fp)
det.sample(5)
# Out:
#                 PLAYER_NAME TEAM_ABBREVIATION   AGE   GP_merge    MIN_merge  \
# PLAYER_ID
# 1497       Chauncey Billups               DET  28.0  58.846154  2148.349103
# 89            Nick Van Exel               POR  33.0  53.000000  1618.058333
# 2745            Kirk Snyder               UTA  22.0  68.000000   900.361667
# 682                Bob Sura               HOU  32.0  50.920000  1599.577622
# 255              Grant Hill               ORL  32.0  67.000000  2342.775000
#
#            FG3M_merge  FG3A_merge  FTM_merge  FTA_merge  OREB_merge  ...  \
# PLAYER_ID                                                            ...
# 1497         1.907692    4.723077   4.492308   5.030769    0.676923  ...
# 89           2.200000    5.700000   1.300000   1.600000    0.400000  ...
# 2745         1.200000    3.400000   2.600000   3.800000    2.000000  ...
# 682          1.074667    2.844000   2.413333   3.294667    1.444000  ...
# 255          0.000000    0.200000   4.300000   5.200000    1.200000  ...
#
#            TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  \
# PLAYER_ID
# 1497            193       273       375        245      402       252
# 89              232       243       449        442      456        49
# 2745            149       258       134        108      128        80
# 682              84       152       410        268      325        13
# 255             107        81       242        298      421       446
#
#            PTS_RANK  PLUS_MINUS_RANK  FG2M_RANK  FG2A_RANK
# PLAYER_ID
# 1497             85               42        313        346
# 89              201              241        383        358
# 2745            179              376        263        177
# 682             264              116        350        370
# 255              28              186          8         15
#
# [5 rows x 41 columns]

# %%
det.select_dtypes("number")
# Out:
#             AGE   GP_merge    MIN_merge  FG3M_merge  FG3A_merge  FTM_merge  \
# PLAYER_ID
# 243        32.0  59.923077   992.399188    0.574359    1.910256   0.261538
# 1425       33.0  42.000000   311.583333    0.000000    0.000000   1.700000
# 1502       30.0  78.000000  1700.976667    0.000000    0.000000   0.800000
# 1559       30.0  60.898734   586.069198    0.087342    0.436709   1.787342
# 1733       25.0  66.000000  2546.448333    0.200000    1.000000   3.300000
# ...         ...        ...          ...         ...         ...        ...
# 2216       23.0  46.000000  1607.248333    0.000000    0.100000   4.600000
# 2560       24.0  40.000000   475.513333    1.000000    2.700000   4.000000
# 2585       21.0  74.000000  1395.963333    0.000000    0.000000   3.600000
# 1442       33.0  58.000000   928.333333    0.000000    0.000000   2.800000
# 980        30.0  78.000000  2615.378333    0.000000    0.100000   5.500000
#
#            FTA_merge  OREB_merge  DREB_merge  AST_merge  ...  TOV_RANK  \
# PLAYER_ID                                                ...
# 243         0.435897    0.574359    4.874359   3.158974  ...       442
# 1425        2.000000    2.000000    5.000000   0.900000  ...       242
# 1502        1.500000    3.500000    5.600000   1.200000  ...       409
# 1559        2.362025    2.711392    5.239241   3.001266  ...       333
# 1733        5.000000    2.000000    4.500000   2.900000  ...        62
# ...              ...         ...         ...        ...  ...       ...
# 2216        5.700000    3.200000    6.700000   1.900000  ...       121
# 2560        4.900000    2.600000    5.100000   1.900000  ...       147
# 2585        4.800000    3.400000    6.400000   1.500000  ...       295
# 1442        3.300000    1.900000    5.200000   1.000000  ...       262
# 980         6.900000    4.100000    5.100000   1.400000  ...        96
#
#            STL_RANK  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  \
# PLAYER_ID
# 243              76       235        403      226        26       456
# 1425            376       126        168       20       387       391
# 1502            389         5        387      161       322       420
# 1559              9       366        356      136       321       371
# 1733            161       338        103      258       320        91
# ...             ...       ...        ...      ...       ...       ...
# 2216            320       249         40      394       162        36
# 2560            321       252        186      134       161        54
# 2585            216       127         87      157       160       255
# 1442            407        70        135       94       159       190
# 980             344        29        106      160       464        51
#
#            PLUS_MINUS_RANK  FG2M_RANK  FG2A_RANK
# PLAYER_ID
# 243                    236        450        460
# 1425                   448        292        323
# 1502                   200        307        369
# 1559                    87        284        229
# 1733                   399         43         51
# ...                    ...        ...        ...
# 2216                   267         17         10
# 2560                    66         72        124
# 2585                   182        205        208
# 1442                   149        103        209
# 980                    104         38         39
#
# [324 rows x 39 columns]

# %%
import os
import logging
import mlflow
from mlflow.tracking import MlflowClient

# %%
rel_path = "../frontend/model"
MLFLOW_TRACKING_URI = os.getenv(
    "MLFLOW_TRACKING_URI", f"sqlite:///{rel_path}/mlflow.db"
)

MLFLOW_REGISTERED_MODEL = os.getenv("MLFLOW_REGISTERED_MODEL", "nba-player-clusterer")

client = MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)
model_filter = f"name='{MLFLOW_REGISTERED_MODEL}'"
mv_search = client.search_model_versions(model_filter)

model_uris = [mv.source for mv in mv_search if mv.current_stage == "Production"]

if model_uris:
    print(f"selected model URI: {model_uris[-1]}")
    # alternatively model_uri could also be direct path to s3 bucket:
    # s3://{MLFLOW_ARTIFACT_STORE}/<exp_id>/<run_id>/artifacts/models
    # the models:/model_name/Production uri is only useable if MLflow server is up
    model = mlflow.pyfunc.load_model(
        # model_uri=f'models:/{MLFLOW_REGISTERED_MODEL}/Production'
        model_uri=Path(rel_path)
        / model_uris[-1]
    )
# Out:
# selected model URI: ./mlruns/2/140228bd53c146b291babded0251bf9a/artifacts/model

# %%
import numpy as np


def reveal_group(data_orig, model: mlflow.pyfunc.PyFuncModel, labels: dict = {}):
    """
    Use a logged model to visualize what label's what
    """
    data = data_orig.copy()
    label_preds = model.predict(data.drop(["PLAYER_NAME", "TEAM_ABBREVIATION"], axis=1))
    data["label_pred"] = label_preds
    # min to incentivize recognizability
    # plus_minus for substance
    data["rank_agg"] = np.sum(
        [
            # data.PTS_RANK,
            # data.DREB_RANK,
            # data.OREB_RANK,
            # data.AST_RANK,
            data.MIN_RANK,
            data.PLUS_MINUS_RANK,
        ],
        axis=0,
    )
    # print(data.columns)

    df_sort = data.groupby("label_pred").apply(
        lambda x: x.sort_values(["rank_agg"], ascending=True)
    )
    # df_samp = []
    if not labels:
        for label in np.unique(label_preds):
            label_samples = df_sort.loc[[label], "PLAYER_NAME"].head(10).sample(3)
            # print(label_samples)
            # df_samp.append(label_samples)
            labels[label] = "-".join(label_samples.values)

    data["label_names"] = data["label_pred"].map(labels)
    # df_merge = pd.concat(df_samp, axis=0)
    # if export_csv:
    #     df_merge.to_csv("./player_labels_sample.csv")
    return labels, data.drop(["rank_agg"], axis=1)

# %%
baa = {}
if not baa:
    print("empty!")
# Out:
# empty!

# %%
labels, labels_df = reveal_group(data_orig=tor, model=model)
labels
# Out:
# {0: 'Anthony Davis-Steven Adams-Paul Millsap',
#  1: 'Draymond Green-Danny Green-Jerami Grant',
#  2: 'James Harden-Khris Middleton-Paul George'}

# %%
labels_df.loc[:, ["PLAYER_NAME", "TEAM_ABBREVIATION", "label_names"]].sample(5)
# Out:
#              PLAYER_NAME TEAM_ABBREVIATION  \
# PLAYER_ID
# 1627782     Wayne Selden               CHI
# 204025       Tim Frazier               MIL
# 203382       Aron Baynes               BOS
# 202339      Eric Bledsoe               MIL
# 203121     Darius Miller               NOP
#
#                                         label_names
# PLAYER_ID
# 1627782     Draymond Green-Danny Green-Jerami Grant
# 204025      Draymond Green-Danny Green-Jerami Grant
# 203382      Anthony Davis-Steven Adams-Paul Millsap
# 202339     James Harden-Khris Middleton-Paul George
# 203121      Draymond Green-Danny Green-Jerami Grant

# %% [markdown]
# ## Finding similar players
#
# We'll run the model again, this time on the 2004-05 season, to cluster the players but apply the same labels. Something tricky to overcome - I need to revise the `reveal_group` function to allow previously constructed labels...

# %%
_, det_label = reveal_group(data_orig=det, model=model, labels=labels)
det_label.loc[:, ["PLAYER_NAME", "TEAM_ABBREVIATION", "label_names"]].sample(5)
# Out:
#                PLAYER_NAME TEAM_ABBREVIATION  \
# PLAYER_ID
# 2484           Devin Brown               SAS
# 1891           Jason Terry               DAL
# 1908         Jumaine Jones               LAL
# 2411       Bostjan Nachbar               NOH
# 2410            Fred Jones               IND
#
#                                        label_names
# PLAYER_ID
# 2484       Draymond Green-Danny Green-Jerami Grant
# 1891       Draymond Green-Danny Green-Jerami Grant
# 1908       Draymond Green-Danny Green-Jerami Grant
# 2411       Draymond Green-Danny Green-Jerami Grant
# 2410       Draymond Green-Danny Green-Jerami Grant

# %%
det_label.sort_values(by=["PLUS_MINUS_RANK"], ascending=True)[
    ["PLAYER_NAME", "TEAM_ABBREVIATION", "label_names"]
].head(5)
# Out:
#                 PLAYER_NAME TEAM_ABBREVIATION  \
# PLAYER_ID
# 1938          Manu Ginobili               SAS
# 1495             Tim Duncan               SAS
# 959              Steve Nash               PHX
# 1725       Rasho Nesterovic               SAS
# 109            Robert Horry               SAS
#
#                                         label_names
# PLAYER_ID
# 1938       James Harden-Khris Middleton-Paul George
# 1495        Anthony Davis-Steven Adams-Paul Millsap
# 959        James Harden-Khris Middleton-Paul George
# 1725        Anthony Davis-Steven Adams-Paul Millsap
# 109         Draymond Green-Danny Green-Jerami Grant

# %% [markdown]
# Great. Next up - for a given player, find the closest analog in the comparison season using these two metrics:
#
# * `PLUS_MINUS_RANK`
# * `MIN_RANK`
#
# Since the number of players will vary between seasons, using the raw rank will not be sufficient. The rank needs to be scaled to the number of players.
#
# This brings into question of how I re-rank the players in the first place. Re-rank occurs *after* the merge, but *before* the player filter. This means that the rank is still league-wide for that season.
#
# I think the rank needs to be standard-scaled at that point, instead of returning the raw rank, so that they can be compared across seasons. This costs one piece of info: how many players are being ranked in that season. Don't think it's that important, but perhaps I can keep it in my column name? e.g. "PTS_RANK_450". No, this raises the issue of incompatible feature names when I use a pre-trained model.
#
# I think I can always retrieve it, if I have the full, unfiltered df to begin with. Instead of saving the filtered pickle, I'll simply append the filter as another column, and save the whole thing.
#
# Revise `train.py` to remove the additional `gametime_threshold` column when feeding to model? Could use `float64` when selecting `dtypes` to exclude `bool`. Nah let's keep it.

# %%
tor.dtypes
# Out:
# PLAYER_NAME           object
# TEAM_ABBREVIATION     object
# AGE                  float64
# GP_merge             float64
# MIN_merge            float64
# FG3M_merge           float64
# FG3A_merge           float64
# FTM_merge            float64
# FTA_merge            float64
# OREB_merge           float64
# DREB_merge           float64
# AST_merge            float64
# TOV_merge            float64
# STL_merge            float64
# BLK_merge            float64
# BLKA_merge           float64
# PF_merge             float64
# PFD_merge            float64
# PTS_merge            float64
# PLUS_MINUS_merge     float64
# FG2M_merge           float64
# FG2A_merge           float64
# GP_RANK                int64
# MIN_RANK               int64
# FG3M_RANK              int64
# FG3A_RANK              int64
# FTM_RANK               int64
# FTA_RANK               int64
# OREB_RANK              int64
# DREB_RANK              int64
# AST_RANK               int64
# TOV_RANK               int64
# STL_RANK               int64
# BLK_RANK               int64
# BLKA_RANK              int64
# PF_RANK                int64
# PFD_RANK               int64
# PTS_RANK               int64
# PLUS_MINUS_RANK        int64
# FG2M_RANK              int64
# FG2A_RANK              int64
# dtype: object
