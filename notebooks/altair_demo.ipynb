# %% [markdown]
# # Altair Demo
#
# Trying out the charts here before moving to streamlit

# %%
import altair as alt
import pandas as pd
from pathlib import Path

# %%
fp = Path("../data/leaguedash_labelled_2018-19.pkl")
# with open(fp, "rb") as f:
#     tor = pickle.load(f)
tor = pd.read_pickle(fp)

# %%
fp = Path("../data/leaguedash_labelled_2004-05.pkl")
# with open(fp, "rb") as f:
#     det = pickle.load(f)
det = pd.read_pickle(fp)

# %% [markdown]
# ## Scatterplot
#
# Scatterplot will be a broad overview of the season's stats:
#
# * FG2A vs FG2M, color=PTS
# * FG3A vs FG3M, color=PTS
# * FG3A vs FG2A, color=PFD
# * AST vs TOV,
# * BLK vs STL, color=PF

# %%
tor.columns
# Out:
# Index(['PLAYER_NAME', 'TEAM_ABBREVIATION', 'AGE', 'GP_merge', 'MIN_merge',
#        'FG3M_merge', 'FG3A_merge', 'FTM_merge', 'FTA_merge', 'OREB_merge',
#        'DREB_merge', 'AST_merge', 'TOV_merge', 'STL_merge', 'BLK_merge',
#        'BLKA_merge', 'PF_merge', 'PFD_merge', 'PTS_merge', 'PLUS_MINUS_merge',
#        'FG2M_merge', 'FG2A_merge', 'GP_RANK', 'MIN_RANK', 'FG3M_RANK',
#        'FG3A_RANK', 'FTM_RANK', 'FTA_RANK', 'OREB_RANK', 'DREB_RANK',
#        'AST_RANK', 'TOV_RANK', 'STL_RANK', 'BLK_RANK', 'BLKA_RANK', 'PF_RANK',
#        'PFD_RANK', 'PTS_RANK', 'PLUS_MINUS_RANK', 'FG2M_RANK', 'FG2A_RANK',
#        'gametime_threshold', 'label_pred', 'label_names'],
#       dtype='object')

# %%
tor.groupby(by="label_pred").agg("count")
# Out:
#             PLAYER_NAME  TEAM_ABBREVIATION  AGE  GP_merge  MIN_merge  \
# label_pred
# 0                   135                135  135       135        135
# 1                   253                253  253       253        253
# 2                   142                142  142       142        142
#
#             FG3M_merge  FG3A_merge  FTM_merge  FTA_merge  OREB_merge  ...  \
# label_pred                                                            ...
# 0                  135         135        135        135         135  ...
# 1                  253         253        253        253         253  ...
# 2                  142         142        142        142         142  ...
#
#             BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  PLUS_MINUS_RANK  \
# label_pred
# 0                135        135      135       135       135              135
# 1                253        253      253       253       253              253
# 2                142        142      142       142       142              142
#
#             FG2M_RANK  FG2A_RANK  gametime_threshold  label_names
# label_pred
# 0                 135        135                 135          135
# 1                 253        253                 253          253
# 2                 142        142                 142          142
#
# [3 rows x 43 columns]

# %%
# from example gallery
# https://altair-viz.github.io/gallery/scatter_linked_table.html

src = tor[tor["gametime_threshold"]][tor["label_pred"] == 2]
brush = alt.selection(type="interval")

# scatterplot
points = (
    alt.Chart(src)
    .mark_point()
    .encode(
        x="FG3A_merge:Q",
        y="FG2A_merge:Q",
        color=alt.condition(brush, "PTS_merge:Q", alt.value("grey")),
    )
    .add_selection(brush)
)
# points

# base chart for data tables
ranked_text = (
    alt.Chart(src)
    .mark_text()
    .encode(y=alt.Y("row_number:O", axis=None))
    .transform_window(row_number="row_number()")
    .transform_filter(brush)
    .transform_window(rank="rank(row_number)")
    .transform_filter(alt.datum.rank < 20)
)

# encoding our data table onto the base
player_name = ranked_text.encode(text="PLAYER_NAME:N").properties(title="Name")
team = ranked_text.encode(text="TEAM_ABBREVIATION:N").properties(title="Team")
pts = ranked_text.encode(text="PTS_merge:Q").properties(title="Points")
text = alt.hconcat(player_name, team, pts)

# build chart
alt.hconcat(
    points,
    text,
).resolve_legend(color="independent")
# Out:
# /tmp/ipykernel_850/2411871560.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   src = tor[tor["gametime_threshold"]][tor["label_pred"] == 2]
# alt.HConcatChart(...)

# %% [markdown]
# The click and drag selection feature is kind of amazing. Perhaps I can further categorize by the cluster labels?
#
# Use `st.checkbox('label_')` for user to select which labels to plot, and perhaps encode via shape, if multiple labels are selected
#
# ## Violinplot
#
# Showcase the distribution of each stat for the two seasons in a shotgun array. Each subplot will have two violins, one for each season.
#
# Let's plot FG2A and FG3A

# %%
tor["season"] = tor.apply(lambda x: "2018-19", axis=1)
det["season"] = det.apply(lambda x: "2004-05", axis=1)
src = pd.concat([tor, det], axis=0)
src.sample(10)
# Out:
#                PLAYER_NAME TEAM_ABBREVIATION   AGE   GP_merge    MIN_merge  \
# PLAYER_ID
# 1629003       Shake Milton               PHI  22.0  20.000000   268.225000
# 2839          James Thomas               ATL  24.0  11.000000   113.181667
# 2038        Joel Przybilla               POR  25.0  76.000000  1857.930000
# 2544          LeBron James               LAL  34.0  55.000000  1937.401667
# 445          Wesley Person               DEN  34.0  34.959184   569.989286
# 467             Jason Kidd               NJN  32.0  59.297297  2204.594324
# 1626169    Stanley Johnson               NOP  23.0  66.000000  1207.370000
# 1628415      Dillon Brooks               MEM  23.0  18.000000   329.895000
# 2397              Yao Ming               HOU  24.0  69.127660  2126.235355
# 2072          Michael Redd               MIL  25.0  75.000000  2852.163333
#
#            FG3M_merge  FG3A_merge  FTM_merge  FTA_merge  OREB_merge  ...  \
# PLAYER_ID                                                            ...
# 1629003      1.900000    5.900000   0.700000   0.900000    1.200000  ...
# 2839         0.000000    0.000000   0.600000   1.900000    5.400000  ...
# 2038         0.000000    0.000000   1.700000   3.400000    3.400000  ...
# 2544         2.100000    6.100000   5.200000   7.800000    1.100000  ...
# 445          2.167347    4.897959   0.418367   0.585714    0.281633  ...
# 467          1.932432    5.364865   2.002703   2.735135    1.464865  ...
# 1626169      1.800000    6.400000   1.500000   1.900000    1.000000  ...
# 1628415      1.600000    4.400000   2.400000   3.300000    1.000000  ...
# 2397         0.000000    0.000000   5.819149   7.538298    3.104255  ...
# 2072         1.300000    3.700000   4.700000   5.500000    0.900000  ...
#
#             PF_RANK  PFD_RANK  PTS_RANK  PLUS_MINUS_RANK  FG2M_RANK  \
# PLAYER_ID
# 1629003    0.281132  0.947170  0.741509         0.409434   0.720755
# 2839       0.387931  0.793103  0.846983         0.971983   0.538793
# 2038       0.265086  0.857759  0.754310         0.683190   0.489224
# 2544       0.933962  0.037736  0.015094         0.239623   0.033962
# 445        0.989224  0.357759  0.379310         0.515086   0.670259
# 467        0.971983  0.769397  0.346983         0.206897   0.715517
# 1626169    0.433962  0.705660  0.547170         0.803774   0.592453
# 1628415    0.073585  0.503774  0.454717         0.530189   0.498113
# 2397       0.295259  0.353448  0.032328         0.282328   0.012931
# 2072       0.956897  0.084052  0.034483         0.594828   0.062500
#
#            FG2A_RANK  gametime_threshold  label_pred  \
# PLAYER_ID
# 1629003     0.709434               False           1
# 2839        0.808190               False           2
# 2038        0.799569                True           2
# 2544        0.049057                True           0
# 445         0.775862               False           1
# 467         0.691810                True           0
# 1626169     0.611321                True           1
# 1628415     0.377358               False           1
# 2397        0.058190                True           2
# 2072        0.056034                True           0
#
#                                                 label_names   season
# PLAYER_ID
# 1629003                 Cory Joseph-Eric Gordon-Jae Crowder  2018-19
# 2839       Udonis Haslem-Zydrunas Ilgauskas-Rasheed Wallace  2004-05
# 2038       Udonis Haslem-Zydrunas Ilgauskas-Rasheed Wallace  2004-05
# 2544             Damian Lillard-Khris Middleton-Paul George  2018-19
# 445                  Bruce Bowen-Jeff McInnis-Shane Battier  2004-05
# 467                Dirk Nowitzki-Kevin Garnett-Shawn Marion  2004-05
# 1626169                 Cory Joseph-Eric Gordon-Jae Crowder  2018-19
# 1628415                 Cory Joseph-Eric Gordon-Jae Crowder  2018-19
# 2397       Udonis Haslem-Zydrunas Ilgauskas-Rasheed Wallace  2004-05
# 2072               Dirk Nowitzki-Kevin Garnett-Shawn Marion  2004-05
#
# [10 rows x 45 columns]

# %%
def make_longform(df):
    """Altair prefers longform structures in its grammar"""
    player_bios = [
        "PLAYER_NAME",
        "TEAM_ABBREVIATION",
        "season",
        "label_names",
        "gametime_threshold",
    ]
    longform = df[df["gametime_threshold"]].melt(
        id_vars=player_bios,
        value_vars=df.drop(player_bios, axis="columns").columns,
        var_name="variable",
        value_name="value",
        ignore_index=False,
    )
    longform = longform.set_index("season", append=True)
    # longform.set_index()
    return longform


src_long = make_longform(src)
src_long.sample(5)

# src_long.set_index('season', append=True).xs("2018-19", level="season").head()
# src_long.set_index('season', append=True).loc[(slice(None) ,"2018-19"),:].head()
# Out:
#                         PLAYER_NAME TEAM_ABBREVIATION  \
# PLAYER_ID season
# 1938      2004-05     Manu Ginobili               SAS
# 1629006   2018-19       Josh Okogie               MIN
# 2736      2004-05         Luol Deng               CHI
# 1628995   2018-19     Kevin Knox II               NYK
# 1905      2004-05  Andrei Kirilenko               UTA
#
#                                                         label_names  \
# PLAYER_ID season
# 1938      2004-05          Dirk Nowitzki-Kevin Garnett-Shawn Marion
# 1629006   2018-19               Cory Joseph-Eric Gordon-Jae Crowder
# 2736      2004-05          Dirk Nowitzki-Kevin Garnett-Shawn Marion
# 1628995   2018-19        Damian Lillard-Khris Middleton-Paul George
# 1905      2004-05  Udonis Haslem-Zydrunas Ilgauskas-Rasheed Wallace
#
#                    gametime_threshold   variable     value
# PLAYER_ID season
# 1938      2004-05                True   PF_merge  3.138333
# 1629006   2018-19                True   PF_merge  3.400000
# 2736      2004-05                True  BLKA_RANK  0.247845
# 1628995   2018-19                True   TOV_RANK  0.422642
# 1905      2004-05                True    PF_RANK  0.814655

# %%
vars = ["FG2A_merge", "FG3A_merge", "PFD_merge"]
# src_a = tor[tor["gametime_threshold"]]
# src_b = det[det["gametime_threshold"]]


def make_violins(df, var, gametime_threshold: bool = True):
    """Make violin charts of var stat grouped by seasons

    Parameters:
    -----------

    df: dataframe, wide-format

    var: str
        column name for which the values will be density transformed

    Returns:
    ---------

    violin: alt.Chart() object
    """
    # use .facet()
    if gametime_threshold:
        df = df.loc[df["gametime_threshold"]]

    # hover = alt.selection_single(on="mouseover", nearest=True, empty="none")

    base = (
        alt.Chart(df)
        .transform_density(
            density=var,
            as_=[var, "density"],
            groupby=["season"],  # don't put :N here
        )
        .mark_area(orient="horizontal")
        .encode(
            y=f"{var}:Q",
            color="season:N",
            x=alt.X(
                "density:Q",
                stack="center",
                impute=None,
                title=None,
                axis=alt.Axis(labels=False, values=[0], grid=False, ticks=False),
            ),
            column=alt.Column(
                "season:N",
                header=alt.Header(
                    titleOrient="bottom",
                    labelAnchor="end",
                    labelOrient="bottom",
                    labelAngle=-30,
                    labelPadding=0,
                ),
            ),
        )
        .properties(width=80)
    )

    return base

# %%
foo = {1: "a", 2: "b", 3: "c"}
while foo:
    print(foo.popitem()[1])
# Out:
# c
# b
# a

# %%
alt.data_transformers.disable_max_rows()
alt.data_transformers.enable("json")
# Out:
# DataTransformerRegistry.enable('json')

# %%
merge_stats = [stat for stat in src.columns if "merge" in stat]
violins = {stat: make_violins(df=src, var=stat) for stat in merge_stats}
# violin_fg3 = make_violins(src, "FG3A_merge")
# violin_fg2 = make_violins(src, "FG2A_merge")
# violin_fg3 | violin_fg2
chart = alt.vconcat()
while violins:
    rows = alt.hconcat()
    for i in range(4):
        if violins:
            rows |= violins.popitem()[1]
    chart &= rows

chart
# Out:
# alt.VConcatChart(...)

# %%
violins["FG2M_merge"]
# Out:
# alt.Chart(...)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 merge_stats = [stat for stat in src.columns if "merge" in stat]
#
# NameError: name 'src' is not defined

# %%
src_long.head()
# Out:
#                PLAYER_NAME TEAM_ABBREVIATION   season  \
# PLAYER_ID
# 0             Aaron Gordon               ORL  2018-19
# 1            Aaron Holiday               IND  2018-19
# 2              Abdel Nader               OKC  2018-19
# 3               Al Horford               BOS  2018-19
# 4          Al-Farouq Aminu               POR  2018-19
#
#                                           label_names  gametime_threshold  \
# PLAYER_ID
# 0          Damian Lillard-Khris Middleton-Paul George                True
# 1                 Cory Joseph-Eric Gordon-Jae Crowder                True
# 2                 Cory Joseph-Eric Gordon-Jae Crowder                True
# 3          Damian Lillard-Khris Middleton-Paul George                True
# 4                 Cory Joseph-Eric Gordon-Jae Crowder                True
#
#           variable  value
# PLAYER_ID
# 0              AGE   23.0
# 1              AGE   22.0
# 2              AGE   25.0
# 3              AGE   33.0
# 4              AGE   28.0

# %%
violin_stat_filter = src_long.apply(lambda x: "merge" in x["variable"], axis=1)
src_long[violin_stat_filter]
# Out:
#                   PLAYER_NAME TEAM_ABBREVIATION   season  \
# PLAYER_ID
# 674              Aaron Gordon               ORL  2018-19
# 675             Aaron Holiday               IND  2018-19
# 676               Abdel Nader               OKC  2018-19
# 677                Al Horford               BOS  2018-19
# 678           Al-Farouq Aminu               POR  2018-19
# ...                       ...               ...      ...
# 13475           Zach Randolph               POR  2004-05
# 13476         Zarko Cabarkapa               GSW  2004-05
# 13477           Zaza Pachulia               MIL  2004-05
# 13478          Zeljko Rebraca               LAC  2004-05
# 13479      Zydrunas Ilgauskas               CLE  2004-05
#
#                                                 label_names  \
# PLAYER_ID
# 674              Damian Lillard-Khris Middleton-Paul George
# 675                     Cory Joseph-Eric Gordon-Jae Crowder
# 676                     Cory Joseph-Eric Gordon-Jae Crowder
# 677              Damian Lillard-Khris Middleton-Paul George
# 678                     Cory Joseph-Eric Gordon-Jae Crowder
# ...                                                     ...
# 13475      Udonis Haslem-Zydrunas Ilgauskas-Rasheed Wallace
# 13476      Udonis Haslem-Zydrunas Ilgauskas-Rasheed Wallace
# 13477      Udonis Haslem-Zydrunas Ilgauskas-Rasheed Wallace
# 13478      Udonis Haslem-Zydrunas Ilgauskas-Rasheed Wallace
# 13479      Udonis Haslem-Zydrunas Ilgauskas-Rasheed Wallace
#
#            gametime_threshold    variable      value
# PLAYER_ID
# 674                      True    GP_merge  69.704545
# 675                      True    GP_merge  44.964286
# 676                      True    GP_merge  55.805970
# 677                      True    GP_merge  55.651163
# 678                      True    GP_merge  62.592920
# ...                       ...         ...        ...
# 13475                    True  FG2A_merge  16.500000
# 13476                    True  FG2A_merge  10.700000
# 13477                    True  FG2A_merge   9.100000
# 13478                    True  FG2A_merge   9.100000
# 13479                    True  FG2A_merge  13.400000
#
# [12806 rows x 7 columns]

# %%
violin_stat_filter.head(5)
# Out:
# PLAYER_ID
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
alt.Chart(
    src_long[src_long["variable"] in set(vars)],
    width=100,
    height=100,
).transform_density(
    "value", groupby=["season", "variable"], as_=["value", "density"]
).mark_area(
    orient="horizontal"
).encode(
    y="value:Q",
    x=alt.X(
        "density:Q",
        stack="center",
        impute=None,
        title=None,
        axis=alt.Axis(labels=False, values=[0], grid=False, ticks=False),
    ),
).facet(
    "variable:N",
    columns=5,
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [34], line 2
#       1 alt.Chart(
# ----> 2     src_long[src_long['variable'] in set(vars)],
#       3     width=100,
#       4     height=100,
#       5 ).transform_density(
#       6     'value',
#       7     groupby=['season', 'variable'],
#       8     as_=['value', 'density']
#       9 ).mark_area(orient='horizontal').encode(
#      10     y='value:Q',
#      11     x=alt.X(
#      12         'density:Q',
#      13         stack='center',
#      14         impute=None,
#      15         title=None,
#      16         axis=alt.Axis(labels=False, values=[0], grid=False, ticks=False),)
#      17 ).facet(
#      18     'variable:N',
#      19     columns=5,
#      20 )
#
# TypeError: unhashable type: 'Series'
